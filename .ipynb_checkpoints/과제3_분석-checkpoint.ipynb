# %% [markdown]
# # [실험설계_과제3] 방사선 조사 식품에 관한 분석

# %%
import numpy as np
import pandas as pd
import pyreadstat

# %%
# !pip install pyreadstat
# Out:
# Collecting pyreadstat
#   Obtaining dependency information for pyreadstat from https://files.pythonhosted.org/packages/d2/e5/3dbee7630a923364f7936d3dc19be304963883c62d35a1118dc5494e07e8/pyreadstat-1.2.3-cp38-cp38-win_amd64.whl.metadata
#   Downloading pyreadstat-1.2.3-cp38-cp38-win_amd64.whl.metadata (1.1 kB)
# Requirement already satisfied: pandas>=1.2.0 in c:\users\seunghyeon\appdata\local\programs\python\python38\lib\site-packages (from pyreadstat) (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\seunghyeon\appdata\local\programs\python\python38\lib\site-packages (from pandas>=1.2.0->pyreadstat) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\seunghyeon\appdata\local\programs\python\python38\lib\site-packages (from pandas>=1.2.0->pyreadstat) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\seunghyeon\appdata\local\programs\python\python38\lib\site-packages (from pandas>=1.2.0->pyreadstat) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\seunghyeon\appdata\local\programs\python\python38\lib\site-packages (from pandas>=1.2.0->pyreadstat) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\seunghyeon\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2.0->pyreadstat) (1.16.0)
# Downloading pyreadstat-1.2.3-cp38-cp38-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    --- ------------------------------------ 0.2/2.4 MB 4.1 MB/s eta 0:00:01
#    ------ --------------------------------- 0.4/2.4 MB 5.0 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.6/2.4 MB 4.4 MB/s eta 0:00:01
#    --------------- ------------------------ 0.9/2.4 MB 5.3 MB/s eta 0:00:01
#    --------------------- ------------------ 1.3/2.4 MB 5.8 MB/s eta 0:00:01
#    ------------------------- -------------- 1.5/2.4 MB 6.0 MB/s eta 0:00:01
#    ------------------------------ --------- 1.9/2.4 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.1/2.4 MB 6.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.4 MB 5.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.2/2.4 MB 4.9 MB/s eta 0:00:01
#    ------------------------------------- -- 2.3/2.4 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  2.4/2.4 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 4.3 MB/s eta 0:00:00
# Installing collected packages: pyreadstat
# Successfully installed pyreadstat-1.2.3

# %%
df_spss = pd.read_spss("C:/Users/SeungHyeon/Desktop/학교/실험설계및분석/과제3/[미션][03][방사선조사식품에관한분석].sav")

# %%
df_spss
# Out:
#    성별   연령 결혼여부  구입경험  섭취경험  구입의향  객관적지식
# 0   남  30대   미혼   0.0   0.0   0.0    4.0
# 1   남  30대   기혼   0.0   0.0   1.0    3.0
# 2   남  40대   기혼   0.0   0.0   1.0    4.0
# 3   남  50대   기혼   0.0   0.0   1.0    6.0
# 4   남  40대   미혼   0.0   1.0   1.0    4.0
# .. ..  ...  ...   ...   ...   ...    ...
# 65  여  40대   기혼   0.0   0.0   1.0    6.0
# 66  여  30대   기혼   0.0   0.0   1.0    6.0
# 67  여  40대   기혼   1.0   1.0   1.0    6.0
# 68  여  50대   기혼   0.0   0.0   0.0    6.0
# 69  여  50대   기혼   0.0   0.0   1.0    6.0
#
# [70 rows x 7 columns]
