# %% [markdown]
# # [실험설계_과제3] 방사선 조사 식품에 관한 분석

# %%
import numpy as np
import pandas as pd
import pyreadstat
import random

# %%
#!pip install pyreadstat

# %%
df_spss = pd.read_spss("C:/Users/SeungHyeon/Desktop/학교/실험설계및분석/과제3/[미션][03][방사선조사식품에관한분석].sav")

# %%
df_spss
# Out:
#    성별   연령 결혼여부  구입경험  섭취경험  구입의향  객관적지식
# 0   남  30대   미혼   0.0   0.0   0.0    4.0
# 1   남  30대   기혼   0.0   0.0   1.0    3.0
# 2   남  40대   기혼   0.0   0.0   1.0    4.0
# 3   남  50대   기혼   0.0   0.0   1.0    6.0
# 4   남  40대   미혼   0.0   1.0   1.0    4.0
# .. ..  ...  ...   ...   ...   ...    ...
# 65  여  40대   기혼   0.0   0.0   1.0    6.0
# 66  여  30대   기혼   0.0   0.0   1.0    6.0
# 67  여  40대   기혼   1.0   1.0   1.0    6.0
# 68  여  50대   기혼   0.0   0.0   0.0    6.0
# 69  여  50대   기혼   0.0   0.0   1.0    6.0
#
# [70 rows x 7 columns]

# %%
pick = random.sample(range(70),45)

# %%
print(pick)
# Out:
# [54, 18, 57, 48, 0, 59, 22, 29, 68, 32, 21, 35, 61, 49, 11, 66, 6, 1, 5, 10, 36, 16, 4, 28, 62, 55, 67, 34, 38, 44, 41, 17, 14, 31, 20, 50, 64, 24, 30, 19, 60, 65, 51, 15, 12]

# %%
sort_pick = list(set(pick))
print(sort_pick)
# Out:
# [0, 1, 4, 5, 6, 10, 11, 12, 14, 15, 16, 17, 18, 19, 20, 21, 22, 24, 28, 29, 30, 31, 32, 34, 35, 36, 38, 41, 44, 48, 49, 50, 51, 54, 55, 57, 59, 60, 61, 62, 64, 65, 66, 67, 68]

# %%
df_spss.loc[sort_pick,:]
# Out:
#    성별   연령 결혼여부  구입경험  섭취경험  구입의향  객관적지식
# 0   남  30대   미혼   0.0   0.0   0.0    4.0
# 1   남  30대   기혼   0.0   0.0   1.0    3.0
# 4   남  40대   미혼   0.0   1.0   1.0    4.0
# 5   남  40대   기혼   1.0   1.0   0.0    4.0
# 6   남  40대   기혼   0.0   0.0   0.0    2.0
# 10  남  40대   기혼   0.0   0.0   1.0    6.0
# 11  남  40대   기혼   0.0   0.0   1.0    6.0
# 12  남  50대   기혼   0.0   0.0   1.0    3.0
# 14  남  50대   기혼   0.0   0.0   1.0    4.0
# 15  남  50대   기혼   0.0   0.0   1.0    4.0
# 16  남  50대   기혼   0.0   0.0   1.0    4.0
# 17  남  30대   미혼   0.0   0.0   0.0    5.0
# 18  남  30대   기혼   0.0   0.0   1.0    5.0
# 19  남  40대   미혼   0.0   0.0   1.0    2.0
# 20  남  40대   기혼   0.0   0.0   1.0    2.0
# 21  남  40대   기혼   1.0   1.0   1.0    2.0
# 22  남  40대   기혼   1.0   1.0   1.0    4.0
# 24  남  40대   기혼   0.0   0.0   1.0    5.0
# 28  남  40대   기혼   0.0   0.0   1.0    1.0
# 29  남  50대   기혼   1.0   1.0   1.0    1.0
# 30  남  50대   기혼   0.0   0.0   0.0    2.0
# 31  남  50대   기혼   0.0   1.0   1.0    6.0
# ...
